# %% [markdown]
# <a href="https://colab.research.google.com/github/yash5891/Machine-Learning-Assignments/blob/main/Untitled34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import requests

# %%
df=sns.load_dataset("tips")

# %%
df.corr()
# Out:
# <ipython-input-5-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
def subtraction():
  c
  return c

# %%
a=map(subtraction,[1,2,3,4])
a

# %%
# define a function that doubles a number
def double(n):
  return n * 2

# create a list of numbers
numbers = [1, 2, 3, 4, 5]

# use the map function to double each number in the list
doubled = map(double, numbers)

# convert the map object to a list and print it
print(list(doubled)) # [2, 4, 6, 8, 10]
# Out:
# [2, 4, 6, 8, 10]

# %%
def add(a,b):

  return  a+b

# %%
a=map(add,[1,21,212],[2,4,6])
print(list(a))
# Out:
# [3, 25, 218]

# %%
# define a function that adds two numbers
def add(x, y):
  return x + y

# create a map object with add function and a tuple of numbers
a = map(add, (1, 21, 212),(1,4,6
))

# convert the map object to a list and print it
print(list(a)) # [2, 22, 214]
# Out:
# [2, 25, 218]

# %%
import requests

response = requests.get('https://rickandmortyapi.com/api')

# %%
response.text
# Out:
# '{"characters":"https://rickandmortyapi.com/api/character","locations":"https://rickandmortyapi.com/api/location","episodes":"https://rickandmortyapi.com/api/episode"}'

# %%
df=response.json()

# %%
import pandas as pd

character_df = pd.DataFrame(character_data['results'])
character_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d27a714a8a92> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 character_df = pd.DataFrame(character_data['results'])
#       4 character_df.head()
#
# NameError: name 'character_data' is not defined

# %%
data = response.json()
data
# Out:
# {'characters': 'https://rickandmortyapi.com/api/character',
#  'locations': 'https://rickandmortyapi.com/api/location',
#  'episodes': 'https://rickandmortyapi.com/api/episode'}

# %%
data['characters']
# Out:
# 'https://rickandmortyapi.com/api/character'

# %%
character_resp = requests.get(data['characters'])
character_resp.status_code
# Out:
# 200

# %%
character_data = character_resp.json()

# %%
character_data.keys()
# Out:
# dict_keys(['info', 'results'])

# %%
character_data['info']
# Out:
# {'count': 826,
#  'pages': 42,
#  'next': 'https://rickandmortyapi.com/api/character?page=2',
#  'prev': None}

# %%
character_data['results'][6:8]
# Out:
# [{'id': 7,
#   'name': 'Abradolf Lincler',
#   'status': 'unknown',
#   'species': 'Human',
#   'type': 'Genetic experiment',
#   'gender': 'Male',
#   'origin': {'name': 'Earth (Replacement Dimension)',
#    'url': 'https://rickandmortyapi.com/api/location/20'},
#   'location': {'name': 'Testicle Monster Dimension',
#    'url': 'https://rickandmortyapi.com/api/location/21'},
#   'image': 'https://rickandmortyapi.com/api/character/avatar/7.jpeg',
#   'episode': ['https://rickandmortyapi.com/api/episode/10',
#    'https://rickandmortyapi.com/api/episode/11'],
#   'url': 'https://rickandmortyapi.com/api/character/7',
#   'created': '2017-11-04T19:59:20.523Z'},
#  {'id': 8,
#   'name': 'Adjudicator Rick',
#   'status': 'Dead',
#   'species': 'Human',
#   'type': '',
#   'gender': 'Male',
#   'origin': {'name': 'unknown', 'url': ''},
#   'location': {'name': 'Citadel of Ricks',
#    'url': 'https://rickandmortyapi.com/api/location/3'},
# ...

# %%
import pandas as pd

character_df = pd.DataFrame(character_data['results'])
character_df
# Out:
#     id                       name   status species  \
# 0    1               Rick Sanchez    Alive   Human
# 1    2                Morty Smith    Alive   Human
# 2    3               Summer Smith    Alive   Human
# 3    4                 Beth Smith    Alive   Human
# 4    5                Jerry Smith    Alive   Human
# 5    6  Abadango Cluster Princess    Alive   Alien
# 6    7           Abradolf Lincler  unknown   Human
# 7    8           Adjudicator Rick     Dead   Human
# 8    9            Agency Director     Dead   Human
# 9   10                 Alan Rails     Dead   Human
# 10  11            Albert Einstein     Dead   Human
# 11  12                  Alexander     Dead   Human
# 12  13               Alien Googah  unknown   Alien
# 13  14                Alien Morty  unknown   Alien
# 14  15                 Alien Rick  unknown   Alien
# 15  16               Amish Cyborg     Dead   Alien
# 16  17                      Annie    Alive   Human
# ...

# %%
## Locations
location_resp = requests.get(data['locations'])
location_data = location_resp.json()
location_df = pd.DataFrame(location_data['results'])
location_df
# Out:
#     id                           name           type  \
# 0    1                  Earth (C-137)         Planet
# 1    2                       Abadango        Cluster
# 2    3               Citadel of Ricks  Space station
# 3    4              Worldender's lair         Planet
# 4    5                   Anatomy Park     Microverse
# 5    6         Interdimensional Cable             TV
# 6    7       Immortality Field Resort         Resort
# 7    8         Post-Apocalyptic Earth         Planet
# 8    9                   Purge Planet         Planet
# 9   10                   Venzenulon 7         Planet
# 10  11                        Bepis 9         Planet
# 11  12               Cronenberg Earth         Planet
# 12  13                       Nuptia 4         Planet
# 13  14                   Giant's Town   Fantasy town
# 14  15                     Bird World         Planet
# 15  16      St. Gloopy Noops Hospital  Space station
# 16  17                  Earth (5-126)         Planet
# ...

# %%
## Episodes
episode_resp = requests.get(data['episodes'])
episode_data = episode_resp.json()
episode_df = pd.DataFrame(episode_data['results'])
episode_df.head()
# Out:
#    id                    name           air_date episode  \
# 0   1                   Pilot   December 2, 2013  S01E01
# 1   2           Lawnmower Dog   December 9, 2013  S01E02
# 2   3            Anatomy Park  December 16, 2013  S01E03
# 3   4  M. Night Shaym-Aliens!   January 13, 2014  S01E04
# 4   5    Meeseeks and Destroy   January 20, 2014  S01E05
#
#                                           characters  \
# 0  [https://rickandmortyapi.com/api/character/1, ...
# 1  [https://rickandmortyapi.com/api/character/1, ...
# 2  [https://rickandmortyapi.com/api/character/1, ...
# 3  [https://rickandmortyapi.com/api/character/1, ...
# 4  [https://rickandmortyapi.com/api/character/1, ...
#
#                                          url                   created
# 0  https://rickandmortyapi.com/api/episode/1  2017-11-10T12:56:33.798Z
# 1  https://rickandmortyapi.com/api/episode/2  2017-11-10T12:56:33.916Z
# 2  https://rickandmortyapi.com/api/episode/3  2017-11-10T12:56:34.022Z
# ...

# %%
episode_resp.status_code
# Out:
# 200

# %%
c1=episode_df[episode_df["air_date"].str.split(", ").str[-1]=='2014']

# %%
character_df[character_df['name']=="Rick Sanchez"]['origin'][0]['name']
# Out:
# 'Earth (C-137)'

# %%
character_df.loc[0,"origin"]
# Out:
# {'name': 'Earth (C-137)', 'url': 'https://rickandmortyapi.com/api/location/1'}

# %%
character_df.iloc[0,1:7:5]
# Out:
# name                                           Rick Sanchez
# origin    {'name': 'Earth (C-137)', 'url': 'https://rick...
# Name: 0, dtype: object

# %%
c2=episode_df[episode_df["air_date"].str.split(", ").str[-1]>="2014"]
c2.sort_values(by=['name','air_date'])
# Out:
#     id                                     name            air_date episode  \
# 11  12                         A Rickle in Time       July 26, 2015  S02E01
# 13  14                 Auto Erotic Assimilation      August 9, 2015  S02E03
# 17  18            Big Trouble in Little Sanchez  September 13, 2015  S02E07
# 9   10     Close Rick-counters of the Rick Kind       April 7, 2014  S01E10
# 15  16                             Get Schwifty     August 23, 2015  S02E05
# 18  19  Interdimensional Cable 2: Tempting Fate  September 20, 2015  S02E08
# 19  20                   Look Who's Purging Now  September 27, 2015  S02E09
# 3    4                   M. Night Shaym-Aliens!    January 13, 2014  S01E04
# 4    5                     Meeseeks and Destroy    January 20, 2014  S01E05
# 12  13                           Mortynight Run      August 2, 2015  S02E02
# 6    7                      Raising Gazorpazorp      March 10, 2014  S01E07
# ...

# %%
import requests
d={}
b=character_df.iloc[2,9]
for i in b:
  response=requests.get(i).json()
  d[response["name"]]=response["air_date"]
d
# Out:
# {'Rick Potion #9': 'January 27, 2014',
#  'Raising Gazorpazorp': 'March 10, 2014',
#  'Rixty Minutes': 'March 17, 2014',
#  'Something Ricked This Way Comes': 'March 24, 2014',
#  'Close Rick-counters of the Rick Kind': 'April 7, 2014',
#  'Ricksy Business': 'April 14, 2014',
#  'A Rickle in Time': 'July 26, 2015',
#  'Auto Erotic Assimilation': 'August 9, 2015',
#  'Total Rickall': 'August 16, 2015',
#  'Get Schwifty': 'August 23, 2015',
#  'The Ricks Must Be Crazy': 'August 30, 2015',
#  'Big Trouble in Little Sanchez': 'September 13, 2015',
#  'Interdimensional Cable 2: Tempting Fate': 'September 20, 2015',
#  "Look Who's Purging Now": 'September 27, 2015',
#  'The Wedding Squanchers': 'October 4, 2015',
#  'The Rickshank Rickdemption': 'April 1, 2017',
#  'Rickmancing the Stone': 'July 30, 2017',
#  'Pickle Rick': 'August 6, 2017',
#  'Vindicators 3: The Return of Worldender': 'August 13, 2017',
#  'The Whirly Dirly Conspiracy': 'August 20, 2017',
# ...

# %%
len(character_df.iloc[4,9])
# Out:
# 39

# %%
len(character_df.loc[character_df['name'] == 'Jerry Smith','episode'][4])
# Out:
# 39

# %%
a=character_df[character_df["created"].str.split("-").str[0]=="2017"][['species','name']]
a.sort_values('name',ascending=False)
# Out:
#    species                       name
# 2    Human               Summer Smith
# 0    Human               Rick Sanchez
# 1    Human                Morty Smith
# 4    Human                Jerry Smith
# 3    Human                 Beth Smith
# 19   Human    Ants in my Eyes Johnson
# 18   Human               Antenna Rick
# 17   Human              Antenna Morty
# 16   Human                      Annie
# 15   Alien               Amish Cyborg
# 14   Alien                 Alien Rick
# 13   Alien                Alien Morty
# 12   Alien               Alien Googah
# 11   Human                  Alexander
# 10   Human            Albert Einstein
# 9    Human                 Alan Rails
# 8    Human            Agency Director
# 7    Human           Adjudicator Rick
# 6    Human           Abradolf Lincler
# 5    Alien  Abadango Cluster Princess

# %%
for i in episode_df[episode_df["episode"]=="S01E05"]['characters'][4]:
  print(requests.get(i).json()['name'])
# Out:
# Rick Sanchez
# Morty Smith
# Beth Smith
# Big Boobed Waitress
# Dale
# Evil Beth Clone
# Evil Jerry Clone
# Evil Summer Clone
# Jerry Smith
# King Jellybean
# Mr. Booby Buyer
# Mr. Meeseeks
# Principal Vagina
# Samantha
# Slippery Stair
# Stair Goblin
# Summer Smith
# Tammy Guetermann
# Tiny-persons advocacy group lawyer
# Giant Judge

# %%
s=set()
for i in episode_df[episode_df["air_date"].str.split(", ").str[-1]=="2014"]['characters']:
  for j in i:
    s.add(requests.get(j).json()['name'])
s
# Out:
# {'Abradolf Lincler',
#  'Alien Mexican Armada',
#  'Alien Morty',
#  'Alien Rick',
#  'Antenna Morty',
#  'Antenna Rick',
#  'Ants in my Eyes Johnson',
#  'Aqua Morty',
#  'Aqua Rick',
#  'Artist Morty',
#  'Attila Starwar',
#  'Baby Legs',
#  'Baby Legs Chief',
#  'Benjamin',
#  'Bepisian',
#  'Beth Sanchez',
#  'Beth Smith',
#  'Big Boobed Waitress',
#  'Birdperson',
#  'Blue Shirt Morty',
#  'Bobby Moynihan',
#  'Brad',
#  'Brad Anderson',
#  'Butter Robot',
#  'Celebrity Jerry',
#  'Chair-homeless',
#  'Chair-person',
#  'Chair-waiter',
#  'Corn detective',
#  'Cowboy Morty',
#  'Cowboy Rick',
#  'Crab Spider',
#  'Cronenberg Morty',
#  'Cronenberg Rick',
#  'Cult Leader Morty',
#  'Cyclops Morty',
#  'Cyclops Rick',
#  'Cynthia',
#  'Dale',
#  'David Letterman',
#  'Davin',
#  'Doofus Rick',
#  'Doopidoo',
#  'Eric Stoltz Mask Morty',
#  'Evil Beth Clone',
#  'Evil Jerry Clone',
#  'Evil Morty',
#  'Evil Rick',
#  'Evil Summer Clone',
#  'Fulgora',
#  'Garmanarnar',
# ...

# %%
character_df.iloc[16,6]
# Out:
# {'name': 'Earth (C-137)', 'url': 'https://rickandmortyapi.com/api/location/1'}

# %%
a=character_df[character_df['name']=="Jerry Smith"]["episode"][4]
b=character_df[character_df["name"]=="Summer Smith"]["episode"][2]
s_s=set()
j_s=set()
for i in a:
  v=requests.get(i).json()['name']
  s_s.add(v)

for i in b:
  v=requests.get(i).json()['name']
  j_s.add(v)
s_s.intersection(j_s)
# Out:
# {'A Rickconvenient Mort',
#  'A Rickle in Time',
#  'Amortycan Grickfitti',
#  'Auto Erotic Assimilation',
#  'Big Trouble in Little Sanchez',
#  'Childrick of Mort',
#  "Claw and Hoarder: Special Ricktim's Morty",
#  'Close Rick-counters of the Rick Kind',
#  'Edge of Tomorty: Rick, Die, Rickpeat',
#  'Get Schwifty',
#  'Gotron Jerrysis Rickvangelion',
#  'Interdimensional Cable 2: Tempting Fate',
#  "Look Who's Purging Now",
#  'Mort Dinner Rick Andre',
#  "Morty's Mind Blowers",
#  'Mortyplicity',
#  'Promortyus',
#  'Raising Gazorpazorp',
#  'Rattlestar Ricklactica',
#  "Rick & Morty's Thanksploitation Spectacular",
#  'Rick Potion #9',
#  'Rickdependence Spray',
#  'Rickmancing the Stone',
#  'Rickmurai Jack',
#  'Ricksy Business',
#  'Rickternal Friendshine of the Spotless Mort',
#  'Rixty Minutes',
#  'Something Ricked This Way Comes',
#  'Star Mort: Rickturn of the Jerri',
#  "The ABC's of Beth",
#  'The Old Man and the Seat',
#  'The Rickchurian Mortydate',
# ...

# %%
a=character_df[character_df['name']=="Amish Cyborg"]["episode"][15]

for i in a:
  for j in requests.get(i).json()['characters']:
    print(requests.get(j).json()['name'])
# Out:
# Rick Sanchez
# Morty Smith
# Summer Smith
# Beth Smith
# Jerry Smith
# Amish Cyborg
# Baby Wizard
# Bearded Lady
# Cousin Nicky
# Duck With Muscles
# Frankenstein's Monster
# Ghost in a Jar
# Hamurai
# Jacob
# Mr. Beauregard
# Mr. Poopybutthole
# Mrs. Refrigerator
# Pencilvester
# Photography Raptor
# Reverse Giraffe
# Sleepy Gary
# Snuffles (Snowball)
# Tinkles
# Uncle Steve

# %%
a=0
b=0
for j,i in enumerate(episode_df["characters"]):
  if len(i)>a:
    a=len(i)
    b=j
episode_df.loc[b,'episode']
# Out:
# 'S01E10'

# %%
episode_df
# Out:
#     id                                     name            air_date episode  \
# 0    1                                    Pilot    December 2, 2013  S01E01
# 1    2                            Lawnmower Dog    December 9, 2013  S01E02
# 2    3                             Anatomy Park   December 16, 2013  S01E03
# 3    4                   M. Night Shaym-Aliens!    January 13, 2014  S01E04
# 4    5                     Meeseeks and Destroy    January 20, 2014  S01E05
# 5    6                           Rick Potion #9    January 27, 2014  S01E06
# 6    7                      Raising Gazorpazorp      March 10, 2014  S01E07
# 7    8                            Rixty Minutes      March 17, 2014  S01E08
# 8    9          Something Ricked This Way Comes      March 24, 2014  S01E09
# 9   10     Close Rick-counters of the Rick Kind       April 7, 2014  S01E10
# 10  11                          Ricksy Business      April 14, 2014  S01E11
# ...
